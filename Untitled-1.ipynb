# %%
import os
from pathlib import Path
from crewai import Agent, Task, Crew, Process, LLM
from crewai_tools import FileReadTool, DirectoryReadTool
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct
from langchain_community.embeddings import OllamaEmbeddings
import PyPDF2
import docx
import re
import json
from typing import Dict, List
import uuid
import time

# Configuration - UPDATED FOR YOUR SYSTEM
DESKTOP_PATH = r"C:\Users\annen\Desktop\resumes"  # Your resume folder
QDRANT_URL = "http://localhost:6333"
COLLECTION_NAME = "resumes_collection"
OLLAMA_MODEL = "mistral:latest"
OLLAMA_BASE_URL = "http://localhost:11434"
EMBEDDING_MODEL = "nomic-embed-text:latest"  # Faster, smaller embedding model

# Initialize Qdrant client
qdrant_client = QdrantClient(url=QDRANT_URL)

# Delete existing collection if it exists (to fix dimension mismatch)
try:
    qdrant_client.delete_collection(collection_name=COLLECTION_NAME)
    print(f"✓ Deleted old collection: {COLLECTION_NAME}")
except:
    pass

# Initialize Ollama embeddings using a faster embedding model
print(f"Initializing embeddings with {EMBEDDING_MODEL}...")
print("Note: If you don't have nomic-embed-text, run: ollama pull nomic-embed-text")
embeddings = OllamaEmbeddings(
    model=EMBEDDING_MODEL,
    base_url=OLLAMA_BASE_URL
)
# Get actual vector size
test_emb = embeddings.embed_query("test")
VECTOR_SIZE = len(test_emb)
print(f"✓ Using {EMBEDDING_MODEL} embeddings (vector size: {VECTOR_SIZE})")

# Initialize Qdrant collection
try:
    qdrant_client.create_collection(
        collection_name=COLLECTION_NAME,
        vectors_config=VectorParams(size=VECTOR_SIZE, distance=Distance.COSINE),
    )
    print(f"✓ Created collection: {COLLECTION_NAME} with vector size: {VECTOR_SIZE}")
except Exception as e:
    print(f"Collection already exists: {COLLECTION_NAME}")


def extract_text_from_pdf(file_path: str) -> str:
    """Extract text from PDF file"""
    try:
        with open(file_path, 'rb') as file:
            pdf_reader = PyPDF2.PdfReader(file)
            text = ""
            for page in pdf_reader.pages:
                text += page.extract_text()
            return text
    except Exception as e:
        return f"Error reading PDF: {str(e)}"


def extract_text_from_docx(file_path: str) -> str:
    """Extract text from DOCX file"""
    try:
        doc = docx.Document(file_path)
        text = "\n".join([paragraph.text for paragraph in doc.paragraphs])
        return text
    except Exception as e:
        return f"Error reading DOCX: {str(e)}"


def extract_resume_info(text: str, filename: str) -> Dict:
    """Extract structured information from resume text"""
    
    # Clean text
    text = text.replace('\x00', '')  # Remove null characters
    
    # Extract email
    email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
    emails = re.findall(email_pattern, text)
    email = emails[0] if emails else "Not found"
    
    # Extract phone - multiple patterns to catch different formats
    phone_patterns = [
        r'(?:Mob|Mobile|Phone|Tel|Cell)[\s#:]*([+]?\d{1,3}[-.\s]?\d{3}[-.\s]?\d{3}[-.\s]?\d{4})',  # Mob#832-803-7434
        r'\+?\d{1,3}[-.\s]?\(?\d{3}\)?[-.\s]?\d{3}[-.\s]?\d{4}',  # (123) 456-7890 or +1-123-456-7890
        r'\b\d{3}[-.\s]?\d{3}[-.\s]?\d{4}\b',  # 123-456-7890 or 123.456.7890
        r'\b\d{10}\b',  # 1234567890
    ]
    
    phone = "Not found"
    for pattern in phone_patterns:
        matches = re.findall(pattern, text, re.IGNORECASE)
        if matches:
            phone = matches[0] if isinstance(matches[0], str) else ''.join(matches[0])
            # Clean up phone number
            phone = re.sub(r'[^\d+\-\s()]', '', phone).strip()
            break
    
    # Extract name - improved logic
    name = "Not found"
    lines = [line.strip() for line in text.split('\n') if line.strip()]
    
    # Method 1: Look for name near the top (first 10 lines)
    for line in lines[:10]:
        # Skip lines that are clearly not names
        if any(skip in line.lower() for skip in ['objective', 'email', 'phone', 'address', 'po box', 'summary', '>', '#']):
            continue
        # Name should be 2-5 words, mostly letters
        words = line.split()
        if 2 <= len(words) <= 5 and all(word[0].isupper() for word in words[:3] if word):
            # Remove any trailing commas, credentials, etc.
            name = re.sub(r',.*', '', line)  # Remove everything after comma
            name = re.sub(r'\s+(MBA|MS|PMP|CISSP|PhD|BSc|BA|MSc).*', '', name, flags=re.IGNORECASE)
            break
    
    # Method 2: If still not found, try to extract from email
    if name == "Not found" and email != "Not found":
        email_name = email.split('@')[0]
        name = email_name.replace('.', ' ').replace('_', ' ').title()
    
    # Method 3: Use filename as fallback
    if name == "Not found":
        name = filename.replace('.pdf', '').replace('.docx', '').replace('_', ' ').title()
    
    # Extract skills (look for skills section with better parsing)
    skills = []
    text_lower = text.lower()
    
    # Find skills section
    skills_keywords = ['skills', 'technical skills', 'core competencies', 'technologies', 'expertise']
    skills_idx = -1
    for keyword in skills_keywords:
        idx = text_lower.find(keyword)
        if idx != -1:
            skills_idx = idx
            break
    
    if skills_idx != -1:
        # Get text after skills keyword (next 1000 chars)
        skills_section = text[skills_idx:skills_idx+1000].lower()
        
        # Expanded tech skills list
        tech_skills = [
            'python', 'java', 'javascript', 'react', 'sql', 'aws', 'azure', 'gcp',
            'docker', 'kubernetes', 'git', 'machine learning', 'ai', 'ml',
            'node', 'nodejs', 'typescript', 'html', 'css', 'angular', 'vue',
            'mongodb', 'postgresql', 'mysql', 'redis', 'django', 'flask',
            'tensorflow', 'pytorch', 'scikit-learn', 'pandas', 'numpy',
            'c++', 'c#', '.net', 'spring', 'hibernate', 'rest api', 'microservices',
            'jenkins', 'ci/cd', 'terraform', 'ansible', 'linux', 'windows',
            'agile', 'scrum', 'jira', 'confluence', 'devops', 'cloud',
            'pci', 'hipaa', 'iso 27001', 'cissp', 'pmp', 'cism', 'cisa',
            'network security', 'cybersecurity', 'penetration testing', 'vulnerability',
            'firewall', 'cisco', 'checkpoint', 'splunk', 'siem', 'sox', 'gdpr'
        ]
        
        for skill in tech_skills:
            if skill in skills_section:
                skills.append(skill.title())
    
    # Remove duplicates and sort
    skills = sorted(list(set(skills)))
    
    # Extract experience years
    exp_patterns = [
        r'(\d+)\+?\s*years?\s+(?:of\s+)?experience',
        r'experience[:\s]+(\d+)\+?\s*years?'
    ]
    experience_years = "Not specified"
    for pattern in exp_patterns:
        match = re.search(pattern, text_lower)
        if match:
            experience_years = f"{match.group(1)} years"
            break
    
    resume_data = {
        "filename": filename,
        "name": name,
        "email": email,
        "phone": phone,
        "skills": skills,
        "experience_years": experience_years,
        "full_text": text[:2000],  # Store first 2000 chars for debugging
        "text_length": len(text)
    }
    
    return resume_data


def process_resumes_and_store():
    """Process all resumes from Desktop and store in Qdrant"""
    
    resume_files = []
    
    # Get all PDF and DOCX files from Desktop
    for file in os.listdir(DESKTOP_PATH):
        if file.endswith(('.pdf', '.docx')):
            resume_files.append(os.path.join(DESKTOP_PATH, file))
    
    print(f"Found {len(resume_files)} resume files on Desktop")
    
    processed_resumes = []
    points = []
    
    for file_path in resume_files:
        filename = os.path.basename(file_path)
        print(f"Processing: {filename}")
        
        # Extract text based on file type
        if file_path.endswith('.pdf'):
            text = extract_text_from_pdf(file_path)
        else:
            text = extract_text_from_docx(file_path)
        
        if "Error" not in text:
            # Extract structured info
            resume_info = extract_resume_info(text, filename)
            processed_resumes.append(resume_info)
            
            # Create embedding with shorter text to speed up processing
            embedding_text = f"Name: {resume_info['name']}\nEmail: {resume_info['email']}\nSkills: {', '.join(resume_info['skills'])}"
            
            print(f"  Creating embedding for {filename}...")
            try:
                embedding = embeddings.embed_query(embedding_text)
                time.sleep(0.2)  # Small delay between embeddings
            except Exception as e:
                print(f"  ⚠ Error creating embedding: {e}")
                continue
            
            # Create point for Qdrant
            point = PointStruct(
                id=str(uuid.uuid4()),
                vector=embedding,
                payload=resume_info
            )
            points.append(point)
    
    # Upload to Qdrant
    if points:
        qdrant_client.upsert(
            collection_name=COLLECTION_NAME,
            points=points
        )
        print(f"\n✓ Successfully stored {len(points)} resumes in Qdrant!")
    
    return processed_resumes


def query_resumes(query: str):
    """Query resumes using natural language"""
    
    # Create embedding for the query
    query_embedding = embeddings.embed_query(query)
    
    # Search in Qdrant
    search_results = qdrant_client.search(
        collection_name=COLLECTION_NAME,
        query_vector=query_embedding,
        limit=5
    )
    
    if not search_results:
        return "No matching resumes found."
    
    # Create LLM using CrewAI's LLM wrapper for Ollama with longer timeout
    llm = LLM(
        model=f"ollama/{OLLAMA_MODEL}",
        base_url=OLLAMA_BASE_URL,
        timeout=300,  # 5 minutes timeout
        temperature=0.3,
        max_tokens=500  # Shorter responses to be faster
    )
    
    # Create agent
    query_agent = Agent(
        role="Resume Query Assistant",
        goal="Answer questions about candidate resumes accurately and conversationally",
        backstory="You are an expert HR assistant who helps find information from candidate resumes.",
        llm=llm,
        verbose=True
    )
    
    # Prepare context from search results (keep it concise)
    context = "Relevant resumes:\n\n"
    for i, result in enumerate(search_results[:3], 1):  # Only use top 3 results
        resume = result.payload
        context += f"{i}. {resume.get('name', 'N/A')}\n"
        context += f"   Email: {resume.get('email', 'N/A')}\n"
        context += f"   Phone: {resume.get('phone', 'N/A')}\n"
        context += f"   Skills: {', '.join(resume.get('skills', []))}\n"
        context += f"   Experience: {resume.get('experience_years', 'Not specified')}\n\n"
    
    # Create task with concise prompt
    query_task = Task(
        description=f"""Answer this query briefly: "{query}"

{context}

Provide a short, direct answer (2-3 sentences max) with the specific information requested.""",
        expected_output="Brief answer to the query",
        agent=query_agent
    )
    
    # Create crew and execute with shorter max iterations
    crew = Crew(
        agents=[query_agent],
        tasks=[query_task],
        process=Process.sequential,
        verbose=True,
        max_iterations=3  # Limit iterations to avoid long processing
    )
    
    result = crew.kickoff()
    return result


def main():
    """Main function to run the resume intelligence system"""
    
    print("=" * 60)
    print("RESUME INTELLIGENCE SYSTEM")
    print("=" * 60)
    
    # Step 1: Process and store resumes
    print("\n[1] Processing resumes from Desktop...")
    processed = process_resumes_and_store()
    
    print(f"\nProcessed {len(processed)} resumes:")
    for resume in processed:
        print(f"  - {resume['name']}")
        print(f"    Email: {resume['email']}")
        print(f"    Phone: {resume['phone']}")
        print(f"    Skills: {', '.join(resume['skills'][:5]) if resume['skills'] else 'None'}")
        print()
    
    # Step 2: Interactive query mode
    print("\n" + "=" * 60)
    print("QUERY MODE - Ask questions about the resumes!")
    print("=" * 60)
    print("Examples:")
    print("  - What is Pranay Reddy's email?")
    print("  - Find candidates with Python skills")
    print("  - Show me personal details of John Doe")
    print("  - Type 'exit' to quit\n")
    
    while True:
        query = input("\n🔍 Your question: ").strip()
        
        if query.lower() in ['exit', 'quit', 'q']:
            print("Goodbye!")
            break
        
        if not query:
            continue
        
        print("\n🤖 Searching and analyzing...")
        answer = query_resumes(query)
        print(f"\n💡 Answer:\n{answer}\n")
        print("-" * 60)


if __name__ == "__main__":
    main()
# Out:
# INFO:httpx:HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: DELETE http://localhost:6333/collections/resumes_collection "HTTP/1.1 200 OK"
# ✓ Deleted old collection: resumes_collection
# Initializing embeddings with nomic-embed-text:latest...
# Note: If you don't have nomic-embed-text, run: ollama pull nomic-embed-text
# ✓ Using nomic-embed-text:latest embeddings (vector size: 768)
# INFO:httpx:HTTP Request: PUT http://localhost:6333/collections/resumes_collection "HTTP/1.1 200 OK"
# ✓ Created collection: resumes_collection with vector size: 768
# ============================================================
# RESUME INTELLIGENCE SYSTEM
# ============================================================
#
# [1] Processing resumes from Desktop...
# Found 12 resume files on Desktop
# Processing: Ahmad Qasem-Resume.pdf
#   Creating embedding for Ahmad Qasem-Resume.pdf...
# Processing: Ashok Kumar.docx
#   Creating embedding for Ashok Kumar.docx...
# Processing: Dexter Nigel Ramkissoon.docx
#   Creating embedding for Dexter Nigel Ramkissoon.docx...
# Processing: Donald Belvin.docx
#   Creating embedding for Donald Belvin.docx...
# Processing: Jumoke-Adekanmi-Web-Developer-2025-03-21.pdf
#   Creating embedding for Jumoke-Adekanmi-Web-Developer-2025-03-21.pdf...
# Processing: Kiran N. Penmetcha's Profile.pdf
#   Creating embedding for Kiran N. Penmetcha's Profile.pdf...
# Processing: Mahesh_Bolikonda (1).pdf
#   Creating embedding for Mahesh_Bolikonda (1).pdf...
# Processing: Mutchie.docx
#   Creating embedding for Mutchie.docx...
# Processing: PRANAY REDDY_DE_Resume.pdf
#   Creating embedding for PRANAY REDDY_DE_Resume.pdf...
# Processing: Resume of Connal Jackson.docx
#   Creating embedding for Resume of Connal Jackson.docx...
# Processing: Software_Developer_Resume.docx
#   Creating embedding for Software_Developer_Resume.docx...
# Processing: ZAMEN_ALADWANI_PROJECT MANAGER_09_01_2023.pdf
#   Creating embedding for ZAMEN_ALADWANI_PROJECT MANAGER_09_01_2023.pdf...
# INFO:httpx:HTTP Request: PUT http://localhost:6333/collections/resumes_collection/points?wait=true "HTTP/1.1 200 OK"
# ✓ Successfully stored 12 resumes in Qdrant!
#
# Processed 12 resumes:
#   - Ahmad Elsheikhq
#     Email: ahmad.elsheikhq@gmail.com
#     Phone: Not found
#     Skills: Agile, Ai
#
#   - Project History
#     Email: Not found
#     Phone: Not found
#     Skills: .Net, Ai, Angular, C#, Ml
#
#   - Dexternigel
#     Email: dexternigel@gmail.com
#     Phone: Not found
#     Skills: Ai, Checkpoint, Cisco, Firewall, Hipaa
#
#   - Donald Belvin
#     Email: donald0099@gmail.com
#     Phone: Not found
#     Skills: Agile, Ai, Cloud, Firewall, Ml
#
#   - Jumokea
#     Email: JumokeA@gmail.com
#     Phone: 212-363-0754
#     Skills: Ai, Aws, Azure, C#, Css
#
#   - Kiran N. Penmetcha
#     Email: KPenmetcha@gmail.com
#     Phone: 626-736-0525
#     Skills: Agile, Ai, Git, Ml
#
#   - Getmaheshb
#     Email: getmaheshb@gmail.com
#     Phone: Not found
#     Skills: Pci
#
#   - WILLIAM E. MUTCHIE
#     Email: jivaniwilliam@hotmail.com
#     Phone: Not found
#     Skills: Cisco, Git, Html, Java, Linux
#
#   - PRANA Y REDD Y
#     Email: pranayreddy9799@gmail.com
#     Phone: 443-406-8983
#     Skills: Azure, Cloud
#
#   - Resume Of Connal Jackson
#     Email: Not found
#     Phone: Not found
#     Skills: None
#
#   - JOHN DOE
#     Email: john.doe@example.com
#     Phone: Not found
#     Skills: .Net, Agile, Ai, Angular, Ansible
#
#   - Zaman Adwani
#     Email: zaman.adwani@gmail.com
#     Phone: Not found
#     Skills: Agile
#
#
# ============================================================
# QUERY MODE - Ask questions about the resumes!
# ============================================================
# Examples:
#   - What is Pranay Reddy's email?
#   - Find candidates with Python skills
#   - Show me personal details of John Doe
#   - Type 'exit' to quit
#
#
# 🤖 Searching and analyzing...
# C:\Users\annen\AppData\Local\Temp\ipykernel_16448\857576124.py:266: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   search_results = qdrant_client.search(
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/resumes_collection/points/search "HTTP/1.1 200 OK"
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: e52751c9-a7c5-4ee0-bcb0-1a06822d323b                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:50:41 - LiteLLM:INFO: utils.py:3258 -
# LiteLLM completion() model= mistral:latest; provider = ollama
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:LiteLLM:
# LiteLLM completion() model= mistral:latest; provider = ollama
# Output()
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resume Query Assistant                                                                                  │
# │                                                                                                                 │
# │  Task: Answer this query briefly: "find data engineer resume"                                                   │
# │                                                                                                                 │
# │  Relevant resumes:                                                                                              │
# │                                                                                                                 │
# │  1. Resume Of Connal Jackson                                                                                    │
# │     Email: Not found                                                                                            │
# │     Phone: Not found                                                                                            │
# │     Skills:                                                                                                     │
# │     Experience: Not specified                                                                                   │
# │                                                                                                                 │
# │  2. Project History                                                                                             │
# │     Email: Not found                                                                                            │
# │     Phone: Not found                                                                                            │
# │     Skills: .Net, Ai, Angular, C#, Ml, Sql                                                                      │
# │     Experience: Not specified                                                                                   │
# │                                                                                                                 │
# │  3. Dexternigel                                                                                                 │
# │     Email: dexternigel@gmail.com                                                                                │
# │     Phone: Not found                                                                                            │
# │     Skills: Ai, Checkpoint, Cisco, Firewall, Hipaa, Pci, Windows                                                │
# │     Experience: Not specified                                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Provide a short, direct answer (2-3 sentences max) with the specific information requested.                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 500 Internal Server Error"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: e52751c9-a7c5-4ee0-bcb0-1a06822d323b                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output:                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────────── LLM Error ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ❌ LLM Call Failed                                                                                             │
# │  Error: litellm.APIConnectionError: OllamaException - {"error":"model requires more system memory (4.9 GiB)     │
# │  than is available (4.5 GiB)"}                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────── Task Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: 326a1252-d0c8-4f67-8f36-5aec359b1ba5                                                                     │
# │  Agent: Resume Query Assistant                                                                                  │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:174, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     173 try:
# --> 174     response = sync_httpx_client.post(
#     175         url=api_base,
#     176         headers=headers,
#     177         data=(
#     178             signed_json_body
#     179             if signed_json_body is not None
#     180             else json.dumps(data)
#     181         ),
#     182         timeout=timeout,
#     183         stream=stream,
#     184         logging_obj=logging_obj,
#     185     )
#     186 except httpx.HTTPStatusError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\llms\custom_httpx\http_handler.py:780, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     779     setattr(e, "status_code", e.response.status_code)
# --> 780     raise e
#     781 except Exception as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\llms\custom_httpx\http_handler.py:762, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     761 response = self.client.send(req, stream=stream)
# --> 762 response.raise_for_status()
#     763 return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Server error '500 Internal Server Error' for url 'http://localhost:11434/api/generate'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/500
#
# During handling of the above exception, another exception occurred:
#
# OllamaError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\main.py:3083, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3077     api_base = (
#    3078         litellm.api_base
#    3079         or api_base
#    3080         or get_secret("OLLAMA_API_BASE")
#    3081         or "http://localhost:11434"
#    3082     )
# -> 3083     response = base_llm_http_handler.completion(
#    3084         model=model,
#    3085         stream=stream,
#    3086         messages=messages,
#    3087         acompletion=acompletion,
#    3088         api_base=api_base,
#    3089         model_response=model_response,
#    3090         optional_params=optional_params,
#    3091         litellm_params=litellm_params,
#    3092         custom_llm_provider="ollama",
#    3093         timeout=timeout,
#    3094         headers=headers,
#    3095         encoding=encoding,
#    3096         api_key=api_key,
#    3097         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    3098         client=client,
#    3099     )
#    3101 elif custom_llm_provider == "ollama_chat":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:470, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config)
#     468     sync_httpx_client = client
# --> 470 response = self._make_common_sync_call(
#     471     sync_httpx_client=sync_httpx_client,
#     472     provider_config=provider_config,
#     473     api_base=api_base,
#     474     headers=headers,
#     475     data=data,
#     476     signed_json_body=signed_json_body,
#     477     timeout=timeout,
#     478     litellm_params=litellm_params,
#     479     logging_obj=logging_obj,
#     480 )
#     481 return provider_config.transform_response(
#     482     model=model,
#     483     raw_response=response,
#    (...)
#     492     json_mode=json_mode,
#     493 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:199, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     198     else:
# --> 199         raise self._handle_error(e=e, provider_config=provider_config)
#     200 except Exception as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:2409, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    2403     raise BaseLLMException(
#    2404         status_code=status_code,
#    2405         message=error_text,
#    2406         headers=error_headers,
#    2407     )
# -> 2409 raise provider_config.get_error_class(
#    2410     error_message=error_text,
#    2411     status_code=status_code,
#    2412     headers=error_headers,
#    2413 )
#
# OllamaError: {"error":"model requires more system memory (4.9 GiB) than is available (4.5 GiB)"}
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[2], line 373
#     369         print("-" * 60)
#     372 if __name__ == "__main__":
# --> 373     main()
#
# Cell In[2], line 367, in main()
#     364     continue
#     366 print("\n🤖 Searching and analyzing...")
# --> 367 answer = query_resumes(query)
#     368 print(f"\n💡 Answer:\n{answer}\n")
#     369 print("-" * 60)
#
# Cell In[2], line 323, in query_resumes(query)
#     314 # Create crew and execute with shorter max iterations
#     315 crew = Crew(
#     316     agents=[query_agent],
#     317     tasks=[query_task],
#    (...)
#     320     max_iterations=3  # Limit iterations to avoid long processing
#     321 )
# --> 323 result = crew.kickoff()
#     324 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\crew.py:707, in Crew.kickoff(self, inputs)
#     704     self._handle_crew_planning()
#     706 if self.process == Process.sequential:
# --> 707     result = self._run_sequential_process()
#     708 elif self.process == Process.hierarchical:
#     709     result = self._run_hierarchical_process()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\crew.py:821, in Crew._run_sequential_process(self)
#     819 def _run_sequential_process(self) -> CrewOutput:
#     820     """Executes tasks sequentially and returns the final output."""
# --> 821     return self._execute_tasks(self.tasks)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\crew.py:927, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     924     futures.clear()
#     926 context = self._get_context(task, task_outputs)
# --> 927 task_output = task.execute_sync(
#     928     agent=agent_to_use,
#     929     context=context,
#     930     tools=cast(list[BaseTool], tools_for_task),
#     931 )
#     932 task_outputs.append(task_output)
#     933 self._process_task_result(task, task_output)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\task.py:454, in Task.execute_sync(self, agent, context, tools)
#     447 def execute_sync(
#     448     self,
#     449     agent: BaseAgent | None = None,
#     450     context: str | None = None,
#     451     tools: list[BaseTool] | None = None,
#     452 ) -> TaskOutput:
#     453     """Execute the task synchronously."""
# --> 454     return self._execute_core(agent, context, tools)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\task.py:581, in Task._execute_core(self, agent, context, tools)
#     579 self.end_time = datetime.datetime.now()
#     580 crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 581 raise e
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\task.py:518, in Task._execute_core(self, agent, context, tools)
#     516 self.processed_by_agents.add(agent.role)
#     517 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 518 result = agent.execute_task(
#     519     task=self,
#     520     context=context,
#     521     tools=tools,
#     522 )
#     524 pydantic_output, json_output = self._export_output(result)
#     525 task_output = TaskOutput(
#     526     name=self.name or self.description,
#     527     description=self.description,
#    (...)
#     533     output_format=self._get_output_format(),
#     534 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\agent.py:489, in Agent.execute_task(self, task, context, tools)
#     479 if e.__class__.__module__.startswith("litellm"):
#     480     # Do not retry on litellm errors
#     481     crewai_event_bus.emit(
#     482         self,
#     483         event=AgentExecutionErrorEvent(
#    (...)
#     487         ),
#     488     )
# --> 489     raise e
#     490 self._times_executed += 1
#     491 if self._times_executed > self.max_retry_limit:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\agent.py:465, in Agent.execute_task(self, task, context, tools)
#     461         result = self._execute_with_timeout(
#     462             task_prompt, task, self.max_execution_time
#     463         )
#     464     else:
# --> 465         result = self._execute_without_timeout(task_prompt, task)
#     467 except TimeoutError as e:
#     468     # Propagate TimeoutError without retry
#     469     crewai_event_bus.emit(
#     470         self,
#     471         event=AgentExecutionErrorEvent(
#    (...)
#     475         ),
#     476     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\agent.py:564, in Agent._execute_without_timeout(self, task_prompt, task)
#     561 if not self.agent_executor:
#     562     raise RuntimeError("Agent executor is not initialized.")
# --> 564 return self.agent_executor.invoke(
#     565     {
#     566         "input": task_prompt,
#     567         "tool_names": self.agent_executor.tools_names,
#     568         "tools": self.agent_executor.tools_description,
#     569         "ask_for_human_input": task.human_input,
#     570     }
#     571 )["output"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\agents\crew_agent_executor.py:167, in CrewAgentExecutor.invoke(self, inputs)
#     164 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     166 try:
# --> 167     formatted_answer = self._invoke_loop()
#     168 except AssertionError:
#     169     self._printer.print(
#     170         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     171         color="red",
#     172     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\agents\crew_agent_executor.py:262, in CrewAgentExecutor._invoke_loop(self)
#     259 except Exception as e:
#     260     if e.__class__.__module__.startswith("litellm"):
#     261         # Do not retry on litellm errors
# --> 262         raise e
#     263     if is_context_length_exceeded(e):
#     264         handle_context_length(
#     265             respect_context_window=self.respect_context_window,
#     266             printer=self._printer,
#    (...)
#     270             i18n=self._i18n,
#     271         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\agents\crew_agent_executor.py:207, in CrewAgentExecutor._invoke_loop(self)
#     196     formatted_answer = handle_max_iterations_exceeded(
#     197         formatted_answer,
#     198         printer=self._printer,
#    (...)
#     202         callbacks=self.callbacks,
#     203     )
#     205 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 207 answer = get_llm_response(
#     208     llm=self.llm,
#     209     messages=self.messages,
#     210     callbacks=self.callbacks,
#     211     printer=self._printer,
#     212     from_task=self.task,
#     213     from_agent=self.agent,
#     214 )
#     215 formatted_answer = process_llm_response(answer, self.use_stop_words)
#     217 if isinstance(formatted_answer, AgentAction):
#     218     # Extract agent fingerprint if available
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\utilities\agent_utils.py:255, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent)
#     248     answer = llm.call(
#     249         messages,  # type: ignore[arg-type]
#     250         callbacks=callbacks,
#     251         from_task=from_task,
#     252         from_agent=from_agent,
#     253     )
#     254 except Exception as e:
# --> 255     raise e
#     256 if not answer:
#     257     printer.print(
#     258         content="Received None or empty response from LLM call.",
#     259         color="red",
#     260     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\utilities\agent_utils.py:248, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent)
#     230 """Call the LLM and return the response, handling any invalid responses.
#     231
#     232 Args:
#    (...)
#     245     ValueError: If the response is None or empty.
#     246 """
#     247 try:
# --> 248     answer = llm.call(
#     249         messages,  # type: ignore[arg-type]
#     250         callbacks=callbacks,
#     251         from_task=from_task,
#     252         from_agent=from_agent,
#     253     )
#     254 except Exception as e:
#     255     raise e
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\llm.py:1111, in LLM.call(self, messages, tools, callbacks, available_functions, from_task, from_agent)
#    1106     if self.stream:
#    1107         return self._handle_streaming_response(
#    1108             params, callbacks, available_functions, from_task, from_agent
#    1109         )
# -> 1111     return self._handle_non_streaming_response(
#    1112         params, callbacks, available_functions, from_task, from_agent
#    1113     )
#    1114 except LLMContextLengthExceededError:
#    1115     # Re-raise LLMContextLengthExceededError as it should be handled
#    1116     # by the CrewAgentExecutor._invoke_loop method, which can then decide
#    1117     # whether to summarize the content or abort based on the respect_context_window flag
#    1118     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\crewai\llm.py:893, in LLM._handle_non_streaming_response(self, params, callbacks, available_functions, from_task, from_agent)
#     887 # --- 1) Make the completion call
#     888 try:
#     889     # Attempt to make the completion call, but catch context window errors
#     890     # and convert them to our own exception type for consistent handling
#     891     # across the codebase. This allows CrewAgentExecutor to handle context
#     892     # length issues appropriately.
# --> 893     response = litellm.completion(**params)
#     895 except ContextWindowExceededError as e:
#     896     # Convert litellm's context window error to our own exception type
#     897     # for consistent handling in the rest of the codebase
#     898     raise LLMContextLengthExceededError(str(e)) from e
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\utils.py:1330, in client.<locals>.wrapper(*args, **kwargs)
#    1326 if logging_obj:
#    1327     logging_obj.failure_handler(
#    1328         e, traceback_exception, start_time, end_time
#    1329     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1330 raise e
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\utils.py:1205, in client.<locals>.wrapper(*args, **kwargs)
#    1203         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1204 # MODEL CALL
# -> 1205 result = original_function(*args, **kwargs)
#    1206 end_time = datetime.datetime.now()
#    1207 if _is_streaming_request(
#    1208     kwargs=kwargs,
#    1209     call_type=call_type,
#    1210 ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\main.py:3427, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3424     return response
#    3425 except Exception as e:
#    3426     ## Map to OpenAI Exception
# -> 3427     raise exception_type(
#    3428         model=model,
#    3429         custom_llm_provider=custom_llm_provider,
#    3430         original_exception=e,
#    3431         completion_kwargs=args,
#    3432         extra_kwargs=kwargs,
#    3433     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2301, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2299 if exception_mapping_worked:
#    2300     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2301     raise e
#    2302 else:
#    2303     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2270, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2268 exception_mapping_worked = True
#    2269 if hasattr(original_exception, "request"):
# -> 2270     raise APIConnectionError(
#    2271         message="{} - {}".format(exception_provider, error_str),
#    2272         llm_provider=custom_llm_provider,
#    2273         model=model,
#    2274         request=original_exception.request,
#    2275     )
#    2276 else:
#    2277     raise APIConnectionError(
#    2278         message="{}\n{}".format(
#    2279             str(original_exception), traceback.format_exc()
#    (...)
#    2285         ),  # stub the request
#    2286     )
#
# APIConnectionError: litellm.APIConnectionError: OllamaException - {"error":"model requires more system memory (4.9 GiB) than is available (4.5 GiB)"}
